# %%
# No terminal, uma vez: python -m pip install openpyxl pandas
import pandas as pd
import openpyxl

# %%
path = r"CD2022_Populacao_2010_Compatibilizada_20231222.xlsx"

# %%
tabela = pd.read_excel(path, header=2)
tabela_limpa = tabela.iloc[0:5570,1:].copy()

# %%
tabela_limpa
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  \
# 0     RO     11.0        15.0  Alta Floresta D'Oeste
# 1     RO     11.0        23.0              Ariquemes
# 2     RO     11.0        31.0                 Cabixi
# 3     RO     11.0        49.0                 Cacoal
# 4     RO     11.0        56.0             Cerejeiras
# ...   ..      ...         ...                    ...
# 5565  GO     52.0     22005.0             Vianópolis
# 5566  GO     52.0     22054.0         Vicentinópolis
# 5567  GO     52.0     22203.0               Vila Boa
# 5568  GO     52.0     22302.0          Vila Propício
# 5569  DF     53.0       108.0               Brasília
#
#       População Município 2010\n(Sinopse)  \
# 0                                 24392.0
# 1                                 90353.0
# 2                                  6313.0
# 3                                 78574.0
# 4                                 17029.0
# ...                                   ...
# ...

# %%
tabela_limpa["Diferenca"] = (tabela["População Censo 2022"] - tabela["População Município 2010\n(Sinopse)"])

tabela_limpa
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  \
# 0     RO     11.0        15.0  Alta Floresta D'Oeste
# 1     RO     11.0        23.0              Ariquemes
# 2     RO     11.0        31.0                 Cabixi
# 3     RO     11.0        49.0                 Cacoal
# 4     RO     11.0        56.0             Cerejeiras
# ...   ..      ...         ...                    ...
# 5565  GO     52.0     22005.0             Vianópolis
# 5566  GO     52.0     22054.0         Vicentinópolis
# 5567  GO     52.0     22203.0               Vila Boa
# 5568  GO     52.0     22302.0          Vila Propício
# 5569  DF     53.0       108.0               Brasília
#
#       População Município 2010\n(Sinopse)  \
# 0                                 24392.0
# 1                                 90353.0
# 2                                  6313.0
# 3                                 78574.0
# 4                                 17029.0
# ...                                   ...
# ...

# %%
tabela_limpa = tabela_limpa.sort_values(by='Diferenca', ascending=False)
tabela_limpa
# Out:
#       UF  COD. UF  COD. MUNIC NOME DO MUNICÍPIO  \
# 111   AM     13.0      2603.0            Manaus
# 5569  DF     53.0       108.0          Brasília
# 3829  SP     35.0     50308.0         São Paulo
# 3848  SP     35.0     52205.0          Sorocaba
# 5417  GO     52.0      8707.0           Goiânia
# ...   ..      ...         ...               ...
# 4931  RS     43.0     14902.0      Porto Alegre
# 169   PA     15.0      1402.0             Belém
# 3247  RJ     33.0      4904.0       São Gonçalo
# 3242  RJ     33.0      4557.0    Rio de Janeiro
# 2162  BA     29.0     27408.0          Salvador
#
#       População Município 2010\n(Sinopse)  \
# 111                             1802014.0
# 5569                            2570160.0
# 3829                           11253503.0
# 3848                             586625.0
# 5417                            1302001.0
# ...                                   ...
# 4931                            1409351.0
# ...

# %%
tabela_limpa.columns
# Out:
# Index(['UF', 'COD. UF', 'COD. MUNIC', 'NOME DO MUNICÍPIO',
#        'População Município 2010\n(Sinopse)',
#        'População 2010 (Alterações de Limites até 2022)1',
#        'População Censo 2022', 'Diferenca'],
#       dtype='str')

# %%
tabela_estado= (
    tabela_limpa.groupby("UF")[[ 'População Município 2010\n(Sinopse)',
       'População 2010 (Alterações de Limites até 2022)1',
       'População Censo 2022', 'Diferenca']]
    .sum()
    .reset_index()
)

# %%
tabela_estado
# Out:
#     UF  População Município 2010\n(Sinopse)  \
# 0   AC                             733559.0
# 1   AL                            3120494.0
# 2   AM                            3483985.0
# 3   AP                             669526.0
# 4   BA                           14016906.0
# 5   CE                            8452381.0
# 6   DF                            2570160.0
# 7   ES                            3514952.0
# 8   GO                            6003788.0
# 9   MA                            6574789.0
# 10  MG                           19597330.0
# 11  MS                            2449024.0
# 12  MT                            3035122.0
# 13  PA                            7581051.0
# 14  PB                            3766528.0
# 15  PE                            8796448.0
# 16  PI                            3118360.0
# 17  PR                           10444526.0
# 18  RJ                           15989929.0
# 19  RN                            3168027.0
# ...

# %%
tabela_estado = tabela_estado.sort_values(by='Diferenca', ascending=False)
tabela_estado
# Out:
#     UF  População Município 2010\n(Sinopse)  \
# 25  SP                           41262199.0
# 23  SC                            6248436.0
# 8   GO                            6003788.0
# 17  PR                           10444526.0
# 10  MG                           19597330.0
# 12  MT                            3035122.0
# 13  PA                            7581051.0
# 2   AM                            3483985.0
# 5   CE                            8452381.0
# 7   ES                            3514952.0
# 11  MS                            2449024.0
# 15  PE                            8796448.0
# 6   DF                            2570160.0
# 14  PB                            3766528.0
# 9   MA                            6574789.0
# 22  RS                           10693929.0
# 21  RR                             450479.0
# 16  PI                            3118360.0
# 24  SE                            2068017.0
# 19  RN                            3168027.0
# ...

# %%
tabela_municipio = tabela_limpa.iloc[0:5570,3:].copy()
tabela_municipio
# Out:
#      NOME DO MUNICÍPIO  População Município 2010\n(Sinopse)  \
# 111             Manaus                            1802014.0
# 5569          Brasília                            2570160.0
# 3829         São Paulo                           11253503.0
# 3848          Sorocaba                             586625.0
# 5417           Goiânia                            1302001.0
# ...                ...                                  ...
# 4931      Porto Alegre                            1409351.0
# 169              Belém                            1393399.0
# 3247       São Gonçalo                             999728.0
# 3242    Rio de Janeiro                            6320446.0
# 2162          Salvador                            2675656.0
#
#       População 2010 (Alterações de Limites até 2022)1  População Censo 2022  \
# 111                                          1802014.0             2063689.0
# 5569                                         2572159.0             2817381.0
# ...

# %%
tabela_municipio.to_csv(r"H:\Python\Aula4\tabela_municipio.csv", sep =";")

# %%
tabela_estado.to_csv(r"H:\Python\Aula4\tabela_estado.csv", sep =";")
